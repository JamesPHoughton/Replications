# %%
# %pylab inline
import pysd
import pandas as pd
print(pysd.__version__)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 0.8.1

# %%
model = pysd.read_vensim('Capability_Trap.mdl')
model.doc()
# Out:
#                                       Real Name  \
# 0                          Adjustment for Labor
# 1                                     Attrition
# 2                              Authorized Labor
# 3                  Average Capability Loss Rate
# 4                Average Duration of Employment
# 5                                  Capabilities
# 6                           Capability Decrease
# 7                        Capability Delay Order
# 8                           Capability Increase
# 9         Change in Required Improvement Effort
# 10                 Change in Time Spent Working
# 11                                   FINAL TIME
# 12             Fraction of Time Spent Improving
# 13               Fraction of Time Spent Working
# 14                   Fractional Change in Labor
# 15                                       Hiring
# 16                                 INITIAL TIME
# 17             Increase in Time Spent Improving
# ...

# %%
res = model.run()

# %%
np.log(1000)
# Out:
# 6.9077552789821368

# %%
np.exp(7)
# Out:
# 1096.6331584284585

# %%
res.loc[1]
# Out:
# Adjustment for Labor                             0.000000
# Attrition                                       50.000000
# Authorized Labor                               100.000000
# Average Capability Loss Rate                     0.500000
# Average Duration of Employment                   2.000000
# Capabilities                                     1.000000
# Capability Decrease                              0.500000
# Capability Delay Order                           3.000000
# Capability Increase                              0.500000
# Change in Required Improvement Effort            0.000000
# Change in Time Spent Working                     0.000000
# FINAL TIME                                       5.000000
# Fraction of Time Spent Improving                 0.200000
# Fraction of Time Spent Working                   0.800000
# Fractional Change in Labor                       0.000000
# Hiring                                          50.000000
# ...

# %%
res[['Time Spent Improving', 'Time Spent Working', 'Maximum Workweek']]
# Out:
#            Time Spent Improving  Time Spent Working  Maximum Workweek
# -1.000000                   8.0                32.0                70
# -0.984375                   8.0                32.0                70
# -0.968750                   8.0                32.0                70
# -0.953125                   8.0                32.0                70
# -0.937500                   8.0                32.0                70
# -0.921875                   8.0                32.0                70
# -0.906250                   8.0                32.0                70
# -0.890625                   8.0                32.0                70
# -0.875000                   8.0                32.0                70
# -0.859375                   8.0                32.0                70
# -0.843750                   8.0                32.0                70
# -0.828125                   8.0                32.0                70
# ...
